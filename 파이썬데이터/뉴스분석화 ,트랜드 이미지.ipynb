# %%
from selenium import webdriver
import time
import datetime
from konlpy.tag import Kkma,Okt
from konlpy.utils import pprint
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt 
import numpy as np
from PIL import *
import os

    
driver =webdriver.Chrome('./chromedriver.exe')
url='https://www.mk.co.kr/news/business/foundation/'
driver.get(url)

# # 기사 크롤링
    
for i in range(1,7):
    if i==4:
        continue
    driver.find_element('xpath','//*[@id="list_area"]/li['+str(i)+']/a').click()
    time.sleep(4)
       
    cnt= str(datetime.datetime.now().year) +str(datetime.datetime.now().month)
    f = open("data/창업"+cnt+".txt","a",newline="", encoding='utf-8')

    text= driver.find_element('xpath','//*[@id="container"]/section/div[3]/section/div[1]/div[1]/div[1]').text
    time.sleep(2)
    print(text)
    f.write
    f.write(text)
    f.write('\n')
    time.sleep(2)
    driver.back()
f.close()


#현재 연, 월값 가져오기
cnt= str(datetime.datetime.now().year) +str(datetime.datetime.now().month)
f = open("data/창업"+cnt+".txt","r",  encoding='utf-8') # 해당월에 해당되는 파일 오픈, 읽기전용

text=f.read()


okt = Okt()
noun= okt. nouns(text)

noun = [word for word in noun if len(word) >= 2]
count= Counter(noun)



# noun_list= count.most_common(20)
# for v in noun_list :
#     print(v)
    
# 작업디렉토리 변경
current_path = os.getcwd()
os.chdir('C:/Users/HANSUNG/git/project/SGLINK/src/main/resources/static/img/bigdata')


# 워드클라우드 이미징
cand_mask=np.array(Image.open('원.png')) #원 이미지가 있어야 함
wc =  WordCloud(
    font_path = 'malgun.ttf', # 한글 글씨체 설정
    background_color='white', # 배경색은 흰색으로 
    colormap='Reds', # 글씨색은 빨간색으로
    mask=cand_mask, # 워드클라우드 모양 설정
).generate_from_frequencies(dict(noun_list))



#사이즈 설정 및 출력
plt.figure(figsize=(8,8))
plt.imshow(wc,interpolation='bilinear')
plt.axis('off') # 차트로 나오지 않게
plt.savefig('창업트랜드'+cnt+'.png',bbox_inches='tight')


# wc = WordCloud(font_path=path, background_color="white" 
#                ,width = 400, height=200, random_state = 20
#                ,max_font_size=60)
# cloud = wc.generate_from_frequencies(dict(noun_list))



# 표시
# plt.figure(figsize=(10,10))
# plt.rc('font', family='Malgun Gothic')
# plt.axis('off')
# plt.imshow(cloud)
# plt.title("창업 트랜드",fontdict=title_font,loc='left')

# plt.savefig('창업트랜드'+cnt+'.png',bbox_inches='tight')
# plt.show()
# Out:
# C:\Users\HANSUNG\AppData\Local\Temp\ipykernel_13016\2851131396.py:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver =webdriver.Chrome('./chromedriver.exe')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py:71, in Service.start(self)
#      70     cmd.extend(self.command_line_args())
# ---> 71     self.process = subprocess.Popen(cmd, env=self.env,
#      72                                     close_fds=system() != 'Windows',
#      73                                     stdout=self.log_file,
#      74                                     stderr=self.log_file,
#      75                                     stdin=PIPE,
#      76                                     creationflags=self.creationflags)
#      77 except TypeError:
#
# ...
